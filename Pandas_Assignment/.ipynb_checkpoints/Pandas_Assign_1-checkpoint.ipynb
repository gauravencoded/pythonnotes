# %%
import pandas as  pd
df=pd.read_csv('/Users/gauravsingh/Desktop/pyspark/data/ASS.csv')
# total order
order_total=df.groupby('customer_id')["value"].count().rename("order_count")
order_total
# customer if with most recent order date
recent_date=df.groupby('customer_id')['date'].max().rename('most_recent_order_date')
# removes duplicate customer_id leaving gender and customer only
gender= df.drop_duplicates(['customer_id'])[['customer_id','gender']]
#merge all data
gender_date=pd.merge(gender, recent_date, on='customer_id', how='inner')
gender_date_order=pd.merge(gender_date, order_total, on='customer_id', how='inner')
res=gender_date_order.sort_values(by=['customer_id'])
res
# Out:
#       customer_id  gender most_recent_order_date  order_count
# 0            1000       0    2017-01-01 00:11:31            1
# 1            1001       0    2017-01-01 00:29:56            1
# 2            1002       1    2017-02-19 21:35:31            3
# 3            1003       1    2017-04-26 02:37:20            4
# 4            1004       0    2017-01-01 03:11:54            1
# 5            1005       1    2017-12-16 01:39:27            2
# 6            1006       1    2017-05-09 15:27:20            3
# 7            1007       0    2017-01-01 15:59:50            1
# 8            1008       0    2017-12-17 05:47:48            3
# 9            1009       1    2017-01-01 19:27:17            1
# 10           1010       1    2017-04-28 13:31:11            2
# 11           1011       1    2017-01-01 22:04:54            1
# 12           1012       1    2017-01-01 22:08:16            1
# 13           1013       0    2017-01-01 23:51:58            1
# 14           1014       1    2017-01-02 00:28:42            1
# 15           1015       0    2017-09-21 19:58:04            4
# 16           1016       1    2017-01-02 01:24:13            1
# 17           1017       0    2017-01-02 02:08:52            2
# 18           1018       0    2017-01-23 01:34:52            2
# 19           1019       0    2017-01-02 02:17:03            1
# 20           1020       0    2017-04-03 02:42:42            3
# 21           1021       1    2017-03-14 00:14:21            2
# 22           1022       0    2017-01-02 03:36:59            1
# 23           1023       0    2017-03-04 21:15:18            4
# 24           1024       1    2017-01-02 05:19:48            1
# 25           1025       0    2017-05-11 19:57:33            3
# 26           1026       0    2017-01-02 14:52:06            1
# 27           1027       0    2017-01-02 15:49:44            1
# 28           1028       0    2017-01-22 22:27:15            2
# 29           1029       0    2017-01-02 17:01:25            1
# ...           ...     ...                    ...          ...
# 8784         9784       0    2017-12-30 20:38:45            1
# 8785         9785       1    2017-12-30 21:12:58            1
# 8786         9786       1    2017-12-30 21:36:03            1
# 8787         9787       1    2017-12-30 23:53:08            1
# 8788         9788       1    2017-12-31 00:26:48            1
# 8789         9789       1    2017-12-31 02:13:42            1
# 8790         9790       0    2017-12-31 03:15:10            1
# 8791         9791       1    2017-12-31 07:29:37            1
# 8792         9792       1    2017-12-31 12:50:05            1
# 8793         9793       0    2017-12-31 14:18:10            1
# 8794         9794       1    2017-12-31 15:13:51            1
# 8795         9795       1    2017-12-31 15:42:08            1
# 8796         9796       0    2017-12-31 16:19:48            1
# 8797         9797       0    2017-12-31 16:36:34            1
# 8798         9798       1    2017-12-31 17:36:37            1
# 8799         9799       1    2017-12-31 18:20:50            1
# 8800         9800       1    2017-12-31 18:33:23            1
# 8801         9801       0    2017-12-31 18:53:32            1
# 8802         9802       1    2017-12-31 18:55:09            1
# 8803         9803       0    2017-12-31 18:57:12            1
# 8804         9804       0    2017-12-31 19:49:44            1
# 8805         9805       1    2017-12-31 20:07:35            1
# 8806         9806       1    2017-12-31 21:08:36            1
# 8807         9807       0    2017-12-31 21:24:08            1
# 8808         9808       1    2017-12-31 21:39:27            1
# 8809         9809       1    2017-12-31 21:39:33            1
# 8810         9810       1    2017-12-31 22:16:20            1
# 8811         9811       1    2017-12-31 22:24:06            1
# 8812         9812       0    2017-12-31 23:01:10            1
# 8813         9813       0    2017-12-31 23:11:02            1
#
# [8814 rows x 4 columns]

# %%
import pandas as  pd
df=pd.read_csv('/Users/gauravsingh/Desktop/pyspark/data/ASS.csv')
df.groupby('gender')['value'].mean()
# Out:
# gender
# 0    363.890006
# 1    350.708361
# Name: value, dtype: float64

# %%
import pandas as  pd
import matplotlib.pyplot as plt
from datetime import datetime
df=pd.read_csv('/Users/gauravsingh/Desktop/pyspark/data/ASS.csv')
df['week']=pd.to_datetime(df['date']).dt.week

sale_per_week=df.groupby('week')['value'].count().rename("order in").reset_index()
plt.plot(sale_per_week)
# Out:
# [<matplotlib.lines.Line2D at 0x11dcaf7f0>,
#  <matplotlib.lines.Line2D at 0x11dcaf940>]
